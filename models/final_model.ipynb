# %%
import time
import pandas as pd 
import numpy as np
import pingouin as pg 
import lightgbm as lgb 
from sklearn.model_selection import train_test_split
from sklearn.model_selection import train_test_split, cross_val_score, cross_validate
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix, roc_auc_score, precision_recall_curve
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import StratifiedKFold
from sklearn.utils.multiclass import unique_labels
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
df = pd.read_csv('fixed_projects.csv')

# %%
replace_values = {'Illicit':1, 'likely-reputable':0}
# replace_values = {1:'Illicit', 0:'likely-reputable'}
df['FLAG'] = df['FLAG'].replace(replace_values)

# %%
X = df.drop(columns = ['Address', 'FLAG'], axis=1)
y = df['FLAG']

# %% [markdown]
# ### Inferential Statistics

# %%
# Correlation between inputs 
corr_matrix = X.corr().abs()

upper = corr_matrix.where(np.triu(np.ones(corr_matrix.shape), k=1).astype(np.bool))
to_drop = [column for column in upper.columns if any(upper[column] > 0.95)]

X.drop(columns=to_drop, axis=1, inplace=True)
# Out:
# /tmp/ipykernel_6885/4228884520.py:4: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   upper = corr_matrix.where(np.triu(np.ones(corr_matrix.shape), k=1).astype(np.bool))

# %% [markdown]
# ### Model Training

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, shuffle=True)

# %%
def stratified_k_fold_LGBM(X, Y, n_folds):
    # import matplotlib
    # matplotlib.use('Agg')
    print("Starting stratified Cross-validation using LGBM")
    #model1 = xgb.XGBClassifier(learning_rate=0.1, n_estimators=1000, max_depth=5, min_child_weight=1, gamma=0,
    #                           subsample=0.8, colsample_bytree=0.8, objective='binary:logistic',
    #                           scale_pos_weight=1, seed=27)
    clf = lgb.LGBMClassifier(learning_rate=0.2)
    max_depth = [2, 3, 4, 5, 6, 7, 8]
    n_estimators = [100, 150, 200, 250, 300]
    param_grid = dict(max_depth=max_depth, n_estimators=n_estimators)

    kfold = StratifiedKFold(n_splits=n_folds, shuffle=True, random_state=7)
    score = {'f1', 'roc_auc', 'accuracy'}
    current = time.time()
    #results = cross_validate(model1, X, Y, cv=kfold, scoring=scoring, return_train_score=True, n_jobs=-1)
    results = GridSearchCV(clf,param_grid, cv=kfold, scoring='roc_auc', n_jobs=6)
    grid_result = results.fit(X, Y)

    # summarize results
    print("Best: %f using %s" % (grid_result.best_score_, grid_result.best_params_))
    means = grid_result.cv_results_['mean_test_score']
    stds = grid_result.cv_results_['std_test_score']
    params = grid_result.cv_results_['params']

    for mean, stdev, param in zip(means, stds, params):
        print("%f (%f) with: %r" % (mean, stdev, param))
    print("Execution time: ", time.time() - current)

    # plot results
    scores = np.array(means).reshape(len(max_depth), len(n_estimators))
    for i, value in enumerate(max_depth):
        plt.plot(n_estimators, scores[i], label='depth: ' + str(value))
    plt.legend()
    plt.xlabel('n_estimators')
    plt.ylabel('AUC')
    plt.show()

# %%
stratified_k_fold_LGBM(X, y, 10)
# Out:
# Starting stratified Cross-validation using LGBM
# Best: 0.999999 using {'max_depth': 2, 'n_estimators': 100}
# 0.999999 (0.000003) with: {'max_depth': 2, 'n_estimators': 100}
# 0.999999 (0.000003) with: {'max_depth': 2, 'n_estimators': 150}
# 0.999998 (0.000007) with: {'max_depth': 2, 'n_estimators': 200}
# 0.999998 (0.000007) with: {'max_depth': 2, 'n_estimators': 250}
# 0.999998 (0.000007) with: {'max_depth': 2, 'n_estimators': 300}
# 0.999995 (0.000014) with: {'max_depth': 3, 'n_estimators': 100}
# 0.999995 (0.000014) with: {'max_depth': 3, 'n_estimators': 150}
# 0.999997 (0.000010) with: {'max_depth': 3, 'n_estimators': 200}
# 0.999997 (0.000010) with: {'max_depth': 3, 'n_estimators': 250}
# 0.999997 (0.000010) with: {'max_depth': 3, 'n_estimators': 300}
# 0.999997 (0.000010) with: {'max_depth': 4, 'n_estimators': 100}
# 0.999997 (0.000010) with: {'max_depth': 4, 'n_estimators': 150}
# 0.999995 (0.000014) with: {'max_depth': 4, 'n_estimators': 200}
# 0.999997 (0.000010) with: {'max_depth': 4, 'n_estimators': 250}
# 0.999998 (0.000007) with: {'max_depth': 4, 'n_estimators': 300}
# 0.999997 (0.000005) with: {'max_depth': 5, 'n_estimators': 100}
# 0.999998 (0.000005) with: {'max_depth': 5, 'n_estimators': 150}
# 0.999999 (0.000003) with: {'max_depth': 5, 'n_estimators': 200}
# 0.999999 (0.000003) with: {'max_depth': 5, 'n_estimators': 250}
# 0.999999 (0.000003) with: {'max_depth': 5, 'n_estimators': 300}
# 0.999995 (0.000008) with: {'max_depth': 6, 'n_estimators': 100}
# 0.999995 (0.000008) with: {'max_depth': 6, 'n_estimators': 150}
# 0.999995 (0.000008) with: {'max_depth': 6, 'n_estimators': 200}
# 0.999995 (0.000008) with: {'max_depth': 6, 'n_estimators': 250}
# 0.999995 (0.000008) with: {'max_depth': 6, 'n_estimators': 300}
# 0.999994 (0.000011) with: {'max_depth': 7, 'n_estimators': 100}
# 0.999997 (0.000007) with: {'max_depth': 7, 'n_estimators': 150}
# 0.999997 (0.000007) with: {'max_depth': 7, 'n_estimators': 200}
# 0.999997 (0.000007) with: {'max_depth': 7, 'n_estimators': 250}
# 0.999997 (0.000007) with: {'max_depth': 7, 'n_estimators': 300}
# 0.999993 (0.000011) with: {'max_depth': 8, 'n_estimators': 100}
# 0.999991 (0.000017) with: {'max_depth': 8, 'n_estimators': 150}
# 0.999990 (0.000020) with: {'max_depth': 8, 'n_estimators': 200}
# 0.999990 (0.000020) with: {'max_depth': 8, 'n_estimators': 250}
# 0.999990 (0.000020) with: {'max_depth': 8, 'n_estimators': 300}
# Execution time:  14.366594314575195

# %%
clf = lgb.LGBMClassifier(learning_rate=0.09,
                            max_depth=8,
                            subsample=0.5, 
                            objective='binary',
                            n_estimators=100)
eval_set = [(X_train, y_train), (X_test, y_test)]
# clf.fit(X_train, y_train, early_stopping_rounds=100, eval_metric=["error", "logloss"],
#           eval_set=eval_set, verbose=True)
clf.fit(X_train, y_train, early_stopping_rounds=100, eval_metric=["error", "logloss"],
              eval_set=eval_set, verbose=True)

# predict
y_pred = clf.predict(X_test)
predicted_values = [round(val) for val in y_pred]

# evaluation 
accuracy = accuracy_score(y_test, predicted_values)
print("Accuracy: %.2f%%" % (accuracy * 100.0))

print(classification_report(y_test, y_pred, digits=4))

# performance metrics 
results = clf.evals_result_
epochs = len(results['training']['binary_error'])
x_axis = range(0, epochs)
plt.rcParams.update({'font.size': 13})

# plotting log loss
fig, ax = plt.subplots()
ax.plot(x_axis, results['training']['binary_logloss'], label='Train')
ax.plot(x_axis, results['valid_1']['binary_logloss'], label='Test')
ax.legend()
plt.ylabel('Log Loss')
plt.xlabel('Number of iterations')
plt.title('LightGBM Log Loss')
plt.show()
# plot classification error
fig, ax = plt.subplots()
ax.plot(x_axis, results['training']['binary_error'], label='Train')
ax.plot(x_axis, results['valid_1']['binary_error'], label='Test')
ax.legend()
plt.ylabel('Classification Error')
plt.xlabel('Number of iterations')
plt.title('LightGBM Classification Error')
plt.show()
# Out:
# /home/malik_cyrus/anaconda3/lib/python3.9/site-packages/lightgbm/sklearn.py:726: UserWarning: 'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. Pass 'early_stopping()' callback via 'callbacks' argument instead.
#   _log_warning("'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. "
# /home/malik_cyrus/anaconda3/lib/python3.9/site-packages/lightgbm/sklearn.py:736: UserWarning: 'verbose' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose' argument is deprecated and will be removed in a future release of LightGBM. "
# [1]	training's binary_error: 0.346484	training's binary_logloss: 0.561783	valid_1's binary_error: 0.371413	valid_1's binary_logloss: 0.574633
# [2]	training's binary_error: 0.346484	training's binary_logloss: 0.494342	valid_1's binary_error: 0.371413	valid_1's binary_logloss: 0.504936
# [3]	training's binary_error: 0.0299373	training's binary_logloss: 0.43835	valid_1's binary_error: 0.0265295	valid_1's binary_logloss: 0.44711
# [4]	training's binary_error: 0.0104433	training's binary_logloss: 0.391174	valid_1's binary_error: 0.0086627	valid_1's binary_logloss: 0.39853
# [5]	training's binary_error: 0.0102112	training's binary_logloss: 0.34959	valid_1's binary_error: 0.00703844	valid_1's binary_logloss: 0.355807
# [6]	training's binary_error: 0.00742632	training's binary_logloss: 0.313859	valid_1's binary_error: 0.00487277	valid_1's binary_logloss: 0.318959
# [7]	training's binary_error: 0.00394523	training's binary_logloss: 0.282212	valid_1's binary_error: 0.00270709	valid_1's binary_logloss: 0.286725
# [8]	training's binary_error: 0.00440938	training's binary_logloss: 0.254445	valid_1's binary_error: 0.0059556	valid_1's binary_logloss: 0.25846
# [9]	training's binary_error: 0.00464145	training's binary_logloss: 0.230275	valid_1's binary_error: 0.0059556	valid_1's binary_logloss: 0.233691
# [10]	training's binary_error: 0.00440938	training's binary_logloss: 0.20848	valid_1's binary_error: 0.0059556	valid_1's binary_logloss: 0.211522
# [11]	training's binary_error: 0.00440938	training's binary_logloss: 0.189103	valid_1's binary_error: 0.00541419	valid_1's binary_logloss: 0.191784
# [12]	training's binary_error: 0.00440938	training's binary_logloss: 0.171819	valid_1's binary_error: 0.00541419	valid_1's binary_logloss: 0.174215
# [13]	training's binary_error: 0.00440938	training's binary_logloss: 0.156354	valid_1's binary_error: 0.00541419	valid_1's binary_logloss: 0.158538
# [14]	training's binary_error: 0.00440938	training's binary_logloss: 0.142421	valid_1's binary_error: 0.00541419	valid_1's binary_logloss: 0.14438
# [15]	training's binary_error: 0.00440938	training's binary_logloss: 0.129817	valid_1's binary_error: 0.00541419	valid_1's binary_logloss: 0.131442
# [16]	training's binary_error: 0.0041773	training's binary_logloss: 0.118532	valid_1's binary_error: 0.00433135	valid_1's binary_logloss: 0.119938
# [17]	training's binary_error: 0.0041773	training's binary_logloss: 0.108304	valid_1's binary_error: 0.00433135	valid_1's binary_logloss: 0.109494
# [18]	training's binary_error: 0.0041773	training's binary_logloss: 0.0990215	valid_1's binary_error: 0.00433135	valid_1's binary_logloss: 0.100006
# [19]	training's binary_error: 0.0041773	training's binary_logloss: 0.0906647	valid_1's binary_error: 0.00433135	valid_1's binary_logloss: 0.0914998
# [20]	training's binary_error: 0.00394523	training's binary_logloss: 0.0830417	valid_1's binary_error: 0.00324851	valid_1's binary_logloss: 0.0837242
# [21]	training's binary_error: 0.00394523	training's binary_logloss: 0.076144	valid_1's binary_error: 0.00324851	valid_1's binary_logloss: 0.0766682
# [22]	training's binary_error: 0.00301694	training's binary_logloss: 0.0698498	valid_1's binary_error: 0.00270709	valid_1's binary_logloss: 0.0703286
# [23]	training's binary_error: 0.00208865	training's binary_logloss: 0.06389	valid_1's binary_error: 0.00108284	valid_1's binary_logloss: 0.0641741
# [24]	training's binary_error: 0.00208865	training's binary_logloss: 0.0586104	valid_1's binary_error: 0.00108284	valid_1's binary_logloss: 0.0588641
# [25]	training's binary_error: 0.00208865	training's binary_logloss: 0.0536937	valid_1's binary_error: 0.00108284	valid_1's binary_logloss: 0.053782
# [26]	training's binary_error: 0.00208865	training's binary_logloss: 0.0493536	valid_1's binary_error: 0.00108284	valid_1's binary_logloss: 0.0494248
# [27]	training's binary_error: 0.00208865	training's binary_logloss: 0.0452949	valid_1's binary_error: 0.00108284	valid_1's binary_logloss: 0.0452248
# [28]	training's binary_error: 0.00208865	training's binary_logloss: 0.0416938	valid_1's binary_error: 0.00108284	valid_1's binary_logloss: 0.0414813
# [29]	training's binary_error: 0.00208865	training's binary_logloss: 0.0383276	valid_1's binary_error: 0.00108284	valid_1's binary_logloss: 0.037997
# [30]	training's binary_error: 0.00139243	training's binary_logloss: 0.0350247	valid_1's binary_error: 0.000541419	valid_1's binary_logloss: 0.0346758
# [31]	training's binary_error: 0.00139243	training's binary_logloss: 0.0320287	valid_1's binary_error: 0.000541419	valid_1's binary_logloss: 0.0316738
# [32]	training's binary_error: 0.00139243	training's binary_logloss: 0.0293058	valid_1's binary_error: 0.000541419	valid_1's binary_logloss: 0.0289574
# [33]	training's binary_error: 0.00092829	training's binary_logloss: 0.026805	valid_1's binary_error: 0.000541419	valid_1's binary_logloss: 0.0265485
# [34]	training's binary_error: 0.00092829	training's binary_logloss: 0.0246709	valid_1's binary_error: 0.000541419	valid_1's binary_logloss: 0.0244069
# [35]	training's binary_error: 0.000696217	training's binary_logloss: 0.0226779	valid_1's binary_error: 0.000541419	valid_1's binary_logloss: 0.0224513
# [36]	training's binary_error: 0.000464145	training's binary_logloss: 0.0207592	valid_1's binary_error: 0.000541419	valid_1's binary_logloss: 0.0206339
# [37]	training's binary_error: 0.000464145	training's binary_logloss: 0.0191004	valid_1's binary_error: 0.000541419	valid_1's binary_logloss: 0.0190137
# [38]	training's binary_error: 0.000232072	training's binary_logloss: 0.0174926	valid_1's binary_error: 0.000541419	valid_1's binary_logloss: 0.0174987
# [39]	training's binary_error: 0.000232072	training's binary_logloss: 0.0161205	valid_1's binary_error: 0.000541419	valid_1's binary_logloss: 0.0161551
# [40]	training's binary_error: 0.000232072	training's binary_logloss: 0.0147834	valid_1's binary_error: 0.000541419	valid_1's binary_logloss: 0.014875
# [41]	training's binary_error: 0.000232072	training's binary_logloss: 0.0135713	valid_1's binary_error: 0.000541419	valid_1's binary_logloss: 0.0137297
# [42]	training's binary_error: 0.000232072	training's binary_logloss: 0.0124411	valid_1's binary_error: 0.000541419	valid_1's binary_logloss: 0.0126753
# [43]	training's binary_error: 0	training's binary_logloss: 0.0114252	valid_1's binary_error: 0.000541419	valid_1's binary_logloss: 0.0117443
# [44]	training's binary_error: 0	training's binary_logloss: 0.0105131	valid_1's binary_error: 0.000541419	valid_1's binary_logloss: 0.0108821
# [45]	training's binary_error: 0	training's binary_logloss: 0.00968185	valid_1's binary_error: 0.000541419	valid_1's binary_logloss: 0.0101072
# [46]	training's binary_error: 0	training's binary_logloss: 0.00887893	valid_1's binary_error: 0.000541419	valid_1's binary_logloss: 0.00940608
# [47]	training's binary_error: 0	training's binary_logloss: 0.00818097	valid_1's binary_error: 0.000541419	valid_1's binary_logloss: 0.00878977
# [48]	training's binary_error: 0	training's binary_logloss: 0.00753122	valid_1's binary_error: 0.000541419	valid_1's binary_logloss: 0.00819552
# [49]	training's binary_error: 0	training's binary_logloss: 0.0069133	valid_1's binary_error: 0.000541419	valid_1's binary_logloss: 0.00757037
# [50]	training's binary_error: 0	training's binary_logloss: 0.00635421	valid_1's binary_error: 0.000541419	valid_1's binary_logloss: 0.00707857
# [51]	training's binary_error: 0	training's binary_logloss: 0.00584462	valid_1's binary_error: 0.000541419	valid_1's binary_logloss: 0.00663372
# [52]	training's binary_error: 0	training's binary_logloss: 0.00538903	valid_1's binary_error: 0.000541419	valid_1's binary_logloss: 0.00623658
# [53]	training's binary_error: 0	training's binary_logloss: 0.00496413	valid_1's binary_error: 0.000541419	valid_1's binary_logloss: 0.00587599
# [54]	training's binary_error: 0	training's binary_logloss: 0.00458543	valid_1's binary_error: 0.000541419	valid_1's binary_logloss: 0.00555422
# [55]	training's binary_error: 0	training's binary_logloss: 0.00422884	valid_1's binary_error: 0.000541419	valid_1's binary_logloss: 0.00525071
# [56]	training's binary_error: 0	training's binary_logloss: 0.00388481	valid_1's binary_error: 0.000541419	valid_1's binary_logloss: 0.00499334
# [57]	training's binary_error: 0	training's binary_logloss: 0.00357782	valid_1's binary_error: 0.000541419	valid_1's binary_logloss: 0.00475355
# [58]	training's binary_error: 0	training's binary_logloss: 0.00330502	valid_1's binary_error: 0.000541419	valid_1's binary_logloss: 0.00453251
# [59]	training's binary_error: 0	training's binary_logloss: 0.00304005	valid_1's binary_error: 0.000541419	valid_1's binary_logloss: 0.00434902
# [60]	training's binary_error: 0	training's binary_logloss: 0.00280525	valid_1's binary_error: 0.000541419	valid_1's binary_logloss: 0.00417797
# [61]	training's binary_error: 0	training's binary_logloss: 0.00259603	valid_1's binary_error: 0.000541419	valid_1's binary_logloss: 0.00401962
# [62]	training's binary_error: 0	training's binary_logloss: 0.00240237	valid_1's binary_error: 0.000541419	valid_1's binary_logloss: 0.00388941
# [63]	training's binary_error: 0	training's binary_logloss: 0.00221377	valid_1's binary_error: 0.000541419	valid_1's binary_logloss: 0.00377732
# [64]	training's binary_error: 0	training's binary_logloss: 0.00205851	valid_1's binary_error: 0.000541419	valid_1's binary_logloss: 0.00367967
# [65]	training's binary_error: 0	training's binary_logloss: 0.00189906	valid_1's binary_error: 0.000541419	valid_1's binary_logloss: 0.00359639
# [66]	training's binary_error: 0	training's binary_logloss: 0.00175006	valid_1's binary_error: 0.000541419	valid_1's binary_logloss: 0.00352622
# [67]	training's binary_error: 0	training's binary_logloss: 0.00161548	valid_1's binary_error: 0.000541419	valid_1's binary_logloss: 0.00340101
# [68]	training's binary_error: 0	training's binary_logloss: 0.0015013	valid_1's binary_error: 0.000541419	valid_1's binary_logloss: 0.00333714
# [69]	training's binary_error: 0	training's binary_logloss: 0.00138804	valid_1's binary_error: 0.000541419	valid_1's binary_logloss: 0.00329971
# [70]	training's binary_error: 0	training's binary_logloss: 0.00128591	valid_1's binary_error: 0.000541419	valid_1's binary_logloss: 0.00317125
# [71]	training's binary_error: 0	training's binary_logloss: 0.00119924	valid_1's binary_error: 0.000541419	valid_1's binary_logloss: 0.00313849
# [72]	training's binary_error: 0	training's binary_logloss: 0.0011111	valid_1's binary_error: 0.000541419	valid_1's binary_logloss: 0.00310898
# [73]	training's binary_error: 0	training's binary_logloss: 0.00102428	valid_1's binary_error: 0.000541419	valid_1's binary_logloss: 0.00298742
# [74]	training's binary_error: 0	training's binary_logloss: 0.00094644	valid_1's binary_error: 0.000541419	valid_1's binary_logloss: 0.0029693
# [75]	training's binary_error: 0	training's binary_logloss: 0.000877771	valid_1's binary_error: 0.000541419	valid_1's binary_logloss: 0.00297175
# [76]	training's binary_error: 0	training's binary_logloss: 0.000812174	valid_1's binary_error: 0.000541419	valid_1's binary_logloss: 0.00296443
# [77]	training's binary_error: 0	training's binary_logloss: 0.00074658	valid_1's binary_error: 0.000541419	valid_1's binary_logloss: 0.00294672
# [78]	training's binary_error: 0	training's binary_logloss: 0.000688209	valid_1's binary_error: 0.000541419	valid_1's binary_logloss: 0.00285953
# [79]	training's binary_error: 0	training's binary_logloss: 0.000637273	valid_1's binary_error: 0.000541419	valid_1's binary_logloss: 0.00286469
# [80]	training's binary_error: 0	training's binary_logloss: 0.000591032	valid_1's binary_error: 0.000541419	valid_1's binary_logloss: 0.00287441
# [81]	training's binary_error: 0	training's binary_logloss: 0.000549017	valid_1's binary_error: 0.000541419	valid_1's binary_logloss: 0.00288674
# [82]	training's binary_error: 0	training's binary_logloss: 0.000507791	valid_1's binary_error: 0.000541419	valid_1's binary_logloss: 0.002902
# [83]	training's binary_error: 0	training's binary_logloss: 0.000472785	valid_1's binary_error: 0.000541419	valid_1's binary_logloss: 0.00292218
# [84]	training's binary_error: 0	training's binary_logloss: 0.000438457	valid_1's binary_error: 0.000541419	valid_1's binary_logloss: 0.002943
# [85]	training's binary_error: 0	training's binary_logloss: 0.000408337	valid_1's binary_error: 0.000541419	valid_1's binary_logloss: 0.00296701
# [86]	training's binary_error: 0	training's binary_logloss: 0.000375746	valid_1's binary_error: 0.000541419	valid_1's binary_logloss: 0.00293
# [87]	training's binary_error: 0	training's binary_logloss: 0.00034905	valid_1's binary_error: 0.000541419	valid_1's binary_logloss: 0.00295721
# [88]	training's binary_error: 0	training's binary_logloss: 0.000320649	valid_1's binary_error: 0.000541419	valid_1's binary_logloss: 0.00297906
# [89]	training's binary_error: 0	training's binary_logloss: 0.000298234	valid_1's binary_error: 0.000541419	valid_1's binary_logloss: 0.00300901
# [90]	training's binary_error: 0	training's binary_logloss: 0.00027576	valid_1's binary_error: 0.000541419	valid_1's binary_logloss: 0.00295452
# [91]	training's binary_error: 0	training's binary_logloss: 0.000254778	valid_1's binary_error: 0.000541419	valid_1's binary_logloss: 0.00299232
# [92]	training's binary_error: 0	training's binary_logloss: 0.000234541	valid_1's binary_error: 0.000541419	valid_1's binary_logloss: 0.00302195
# [93]	training's binary_error: 0	training's binary_logloss: 0.000216144	valid_1's binary_error: 0.000541419	valid_1's binary_logloss: 0.00305362
# [94]	training's binary_error: 0	training's binary_logloss: 0.000200049	valid_1's binary_error: 0.000541419	valid_1's binary_logloss: 0.00300639
# [95]	training's binary_error: 0	training's binary_logloss: 0.000185174	valid_1's binary_error: 0.000541419	valid_1's binary_logloss: 0.00304929
# [96]	training's binary_error: 0	training's binary_logloss: 0.000170997	valid_1's binary_error: 0.000541419	valid_1's binary_logloss: 0.00308528
# [97]	training's binary_error: 0	training's binary_logloss: 0.000158859	valid_1's binary_error: 0.000541419	valid_1's binary_logloss: 0.00309601
# [98]	training's binary_error: 0	training's binary_logloss: 0.000147254	valid_1's binary_error: 0.000541419	valid_1's binary_logloss: 0.00314119
# [99]	training's binary_error: 0	training's binary_logloss: 0.000135842	valid_1's binary_error: 0.000541419	valid_1's binary_logloss: 0.00312435
# [100]	training's binary_error: 0	training's binary_logloss: 0.000125688	valid_1's binary_error: 0.000541419	valid_1's binary_logloss: 0.00316443
# Accuracy: 99.95%
#               precision    recall  f1-score   support
#
#            0     1.0000    0.9991    0.9996      1161
#            1     0.9985    1.0000    0.9993       686
#
#     accuracy                         0.9995      1847
#    macro avg     0.9993    0.9996    0.9994      1847
# weighted avg     0.9995    0.9995    0.9995      1847

# %%
print(classification_report(y_test, y_pred, digits=4))
# Out:
#               precision    recall  f1-score   support
#
#            0     1.0000    0.9991    0.9996      1161
#            1     0.9985    1.0000    0.9993       686
#
#     accuracy                         0.9995      1847
#    macro avg     0.9993    0.9996    0.9994      1847
# weighted avg     0.9995    0.9995    0.9995      1847

# %% [markdown]
# ### Confusion Matrix

# %%
# confusion matrix
cm = confusion_matrix(y_test, y_pred)
cm_df = pd.DataFrame(cm,
                     index = ['Illicit', 'likely-reputable'], 
                     columns = ['Illicit', 'likely-reputable'])

plt.figure(figsize=(8,6))
sns.heatmap(cm_df, annot=True, fmt='d', cmap='GnBu')
plt.title('Confusion Matrix')
plt.ylabel('Actal Values')
plt.xlabel('Predicted Values')
plt.show()

# %% [markdown]
# ### Random Forest Classifier

# %%
rfc = RandomForestClassifier()
rfc_model = rfc.fit(X_train, y_train)
pred8 = rfc_model.predict(X_test)
print("Accuracy for Random Forest Model: %.2f" % (accuracy_score(y_test, pred8) * 100))
print(classification_report(y_test, pred8, digits=4))
roc = roc_auc_score(y_test, rfc_model.predict_proba(X_test)[:, 1])
print("ROC:" , roc)
# Out:
# Accuracy for Random Forest Model: 99.84
#               precision    recall  f1-score   support
#
#            0     0.9983    0.9991    0.9987      1161
#            1     0.9985    0.9971    0.9978       686
#
#     accuracy                         0.9984      1847
#    macro avg     0.9984    0.9981    0.9983      1847
# weighted avg     0.9984    0.9984    0.9984      1847
#
# ROC: 0.9999937221104758

# %% [markdown]
# ### Logistic Regression for Classification

# %%
#  normalizing data set 
X_train_reg = StandardScaler().fit_transform(X_train)
X_test_reg = StandardScaler().fit_transform(X_test)

# %%
lgr = LogisticRegression(max_iter=100000)
lgr.fit(X_train_reg, y_train)

y_pred_reg = lgr.predict(X_test_reg)
print("Accuracy of logistic regression classifier on test set: {:.4f}".format(accuracy_score(y_test, y_pred_reg)))
# Out:
# Accuracy of logistic regression classifier on test set: 0.9155

# %%
print("Accuracy of logistic regression classifier on test set: {:.4f}".format(accuracy_score(y_test, y_pred_reg)))
# Out:
# Accuracy of logistic regression classifier on test set: 0.9155

# %%
from sklearn import metrics
fpr, tpr, thresholds = metrics.roc_curve(y_test, y_pred_reg)
metrics.auc(fpr, tpr)
# Out:
# 0.9307291392009001

# %%
cfm = confusion_matrix(y_test, y_pred)
print(cfm)
# Out:
# [[1160    1]
#  [   0  686]]

# %%
print(classification_report(y_test, y_pred, digits=4))
# Out:
#               precision    recall  f1-score   support
#
#            0     1.0000    0.9991    0.9996      1161
#            1     0.9985    1.0000    0.9993       686
#
#     accuracy                         0.9995      1847
#    macro avg     0.9993    0.9996    0.9994      1847
# weighted avg     0.9995    0.9995    0.9995      1847

# %% [markdown]
# ### Predict Probability using LGBM

# %%
prob_of_projects = clf.predict_proba(df.drop(columns = ['Address', 'FLAG','Unique_Received_From_Addresses',
                                                        'avg_val_received','avg_val_sent', 'ERC20_total_Ether_received',
                                                        'ERC20_total_Ether_sent_contract', 'ERC20_avg_time_between_contract_tnx', 'ERC20_max_val_rec',
                                                        'ERC20_avg_val_rec', 'ERC20_min_val_sent', 'ERC20_max_val_sent', 'ERC20_avg_val_sent',
                                                        'ERC20_uniq_rec_token_name'], axis=1))

# %%
df['prob_reputable'] = prob_of_projects[:, 0]
df['prob_illicit'] = prob_of_projects[:, 1]

# %%
df
# Out:
#                                          Address  FLAG  \
# 0     0x0020731604c882cf7bf8c444be97d17b19ea4316     1
# 1     0x002bf459dc58584d58886169ea0e80f3ca95ffaf     1
# 2     0x002f0c8119c16d310342d869ca8bf6ace34d9c39     1
# 3     0x0059b14e35dab1b4eee1e2926c7a5660da66f747     1
# 4     0x005b9f4516f8e640bbe48136901738b323c53b00     1
# ...                                          ...   ...
# 6151  0x0ec78ed49c2d27b315d462d43b5bab94d2c79bf8     0
# 6152  0xcbc1aa6961b28cccb11e1cddd84ad8b42ec920b1     0
# 6153  0xa4ef4b0b23c1fc81d3f9ecf93510e64f58a4a016     0
# 6154  0x033e223870f766644f7f7a4b7dc2e91573707d06     0
# 6155  0x1be56412c9606e7285280f76a105eba56996e491     0
#
#       Avg_min_between_sent_tnx  Avg_min_between_received_tnx  Sent_tnx  \
# 0                      1457.31                     34.120000       3.0
# 1                      3976.50                    834.770000       2.0
# 2                       112.90                     31.870000       2.0
# 3                      2300.37                     65.100000      29.0
# 4                         0.00                      0.000000       0.0
# ...                        ...                           ...       ...
# 6151                      0.00                     55.472184       0.0
# 6152                      0.00                     55.472184       0.0
# 6153                      0.00                     55.472184       0.0
# 6154                      0.00                     55.472184       0.0
# 6155                      0.00                     55.472184       0.0
#
#       Received_Tnx  Unique_Received_From_Addresses  Unique_Sent_To_Addresses  \
# 0             13.0                            10.0                       3.0
# 1              2.0                             1.0                       2.0
# 2              3.0                             3.0                       1.0
# 3             98.0                            89.0                      26.0
# 4              0.0                             0.0                       0.0
# ...            ...                             ...                       ...
# 6151           0.0                             0.0                       0.0
# 6152           0.0                             0.0                       0.0
# 6153           0.0                             0.0                       0.0
# 6154           0.0                             0.0                       0.0
# 6155           0.0                             0.0                       0.0
#
#       min_value_received  max_value_received  ...  ERC20_min_val_rec  \
# 0               1.000000            2.501052  ...       1.337000e+00
# 1               0.586269            0.947515  ...       1.337000e+00
# 2               0.001020            0.817800  ...       1.337000e+00
# 3               0.000784           15.729068  ...       0.000000e+00
# 4               0.000000            0.000000  ...       1.337000e+00
# ...                  ...                 ...  ...                ...
# 6151            0.000008          224.672822  ...       1.000000e+02
# 6152            0.000008          224.672822  ...       4.400000e-17
# 6153            0.000008          224.672822  ...       1.510603e+02
# 6154            0.000008          224.672822  ...       6.900000e-08
# 6155            0.000008          224.672822  ...       0.000000e+00
#
#       ERC20_max_val_rec  ERC20_avg_val_rec  ERC20_min_val_sent  \
# 0          1.337000e+01       1.337000e+01        0.000000e+00
# 1          1.337000e+00       1.337000e+00        0.000000e+00
# 2          1.337000e+00       1.337000e+00        0.000000e+00
# 3          2.643608e+04       1.954485e+03        0.000000e+00
# 4          1.337000e+01       1.337000e+01        0.000000e+00
# ...                 ...                ...                 ...
# 6151       1.000000e+02       1.000000e+02        0.000000e+00
# 6152       2.320000e-11       2.132394e-14        7.200000e-17
# 6153       1.812000e+03       9.815301e+02        0.000000e+00
# 6154       6.900000e-08       6.900000e-08        0.000000e+00
# 6155       1.600000e-04       6.099800e-06        8.242451e-09
#
#       ERC20_max_val_sent  ERC20_avg_val_sent  ERC20_uniq_sent_token_name  \
# 0           0.000000e+00        0.000000e+00                         0.0
# 1           0.000000e+00        0.000000e+00                         0.0
# 2           0.000000e+00        0.000000e+00                         0.0
# 3           8.132407e+04        5.232816e+03                        22.0
# 4           0.000000e+00        0.000000e+00                         0.0
# ...                  ...                 ...                         ...
# 6151        0.000000e+00        0.000000e+00                         0.0
# 6152        2.320000e-11        4.119184e-14                         1.0
# 6153        0.000000e+00        0.000000e+00                         0.0
# 6154        0.000000e+00        0.000000e+00                         0.0
# 6155        1.610000e-04        1.527135e-05                         1.0
#
#       ERC20_uniq_rec_token_name  prob_reputable  prob_illicit
# 0                           1.0        0.012862      0.987138
# 1                           1.0        0.012965      0.987035
# 2                           1.0        0.012965      0.987035
# 3                          37.0        0.033476      0.966524
# 4                           1.0        0.012977      0.987023
# ...                         ...             ...           ...
# 6151                        1.0        0.992911      0.007089
# 6152                        1.0        0.992911      0.007089
# 6153                        2.0        0.992911      0.007089
# 6154                        1.0        0.992910      0.007090
# 6155                        1.0        0.992911      0.007089
#
# [6156 rows x 40 columns]

# %% [markdown]
# ### Feature Importance

# %%
def plotImp(model, X , num = 20, fig_size = (40, 20)):
    feature_imp = pd.DataFrame({'Value':model.feature_importances_,'Feature':X.columns})
    plt.figure(figsize=fig_size)
    sns.set(font_scale = 2)
    sns.barplot(x="Value", y="Feature", data=feature_imp.sort_values(by="Value", 
                                                        ascending=False)[0:num])
    plt.title('LightGBM Features (avg over folds)')
    plt.tight_layout()
    # plt.savefig('lgbm_importances-01.png')
    plt.show()

# %%
# X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, shuffle=True)
# clf = lgb.LGBMClassifier(learning_rate=0.09,
#                             max_depth=2,
#                             subsample=0.5, 
#                             objective='binary',
#                             n_estimators=100)
# eval_set = [(X_train, y_train), (X_test, y_test)]
# clf.fit(X_train, y_train, early_stopping_rounds=100, eval_metric=["error", "logloss"],
#               eval_set=eval_set, verbose=True)

# # predict
# y_pred = clf.predict(X_test)
# predicted_values = [round(val) for val in y_pred]

# # evaluation 
# accuracy = accuracy_score(y_test, predicted_values)
# print("Accuracy: %.2f%%" % (accuracy * 100.0))
clf.importance_type = 'split'
plotImp(clf, X)
# plt.savefig('feature_importance_gain.png')

clf.importance_type = 'gain'
plotImp(clf, X)
# plt.savefig('feature_importance_gain.png')
